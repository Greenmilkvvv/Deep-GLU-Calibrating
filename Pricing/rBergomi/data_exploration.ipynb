# %% [markdown]
# # rough Bergomi 探索性数据分析

# %%
import gzip
import numpy as np

import matplotlib.pyplot as plt
import torch.utils
plt.rcParams['font.sans-serif'] = ['SimSun']  # 用来正常显示中文宋体
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
import matplotlib.ticker as mtick

# %%
from rBergomi_utils import data_read, ImpVol_surface_3d

# %% [markdown]
# ## 数据读取

# %%
xx, yy, strikes, maturities = data_read(r"../../Data/rBergomiTrainSet.txt.gz")
# Out:
# 网格数据形状：(40000, 92)
# 参数形状：(40000, 4)
# 隐含波动率曲面形状：(40000, 88)
# 参数上界: [ 0.16      4.       -0.100011  0.499998]
# 参数下界: [ 0.0100133  0.300028  -0.949934   0.0250066]

# %% [markdown]
# ## 隐含波动率曲面

# %%
ImpVol_surface_3d(xx, yy, params_index=19999)
